# %%
# Config box

d = {"key": "value", "key1": "value1"}

# %%
from box import ConfigBox

# %%
d2 = ConfigBox(d)

# %%
d2.key
# Out:
# 'value'

# %% [markdown]
# ### Download data from Kaggle API

# %%
import os

# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/Users/cgouvatsou/Documents/Repositories/Kidney-Disease-Classification/data'

# %%
os.system("kaggle datasets download -d nazmul0087/ct-kidney-dataset-normal-cyst-tumor-and-stone")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nazmul0087/ct-kidney-dataset-normal-cyst-tumor-and-stone
# License(s): Attribution 4.0 International (CC BY 4.0)
# ...
# 100%|█████████▉| 1.51G/1.52G [08:08<00:00, 27.3MB/s]
# 100%|██████████| 1.52G/1.52G [08:08<00:00, 3.33MB/s]
# 0

# %%
fileid = url.split("/")
fileid = fileid[-2]

# %%
prefix = "https://drive.google.com/uc?id="
gdown.
