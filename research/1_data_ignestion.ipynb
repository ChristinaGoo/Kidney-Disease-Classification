# %%
import os
os.chdir("../")
os.getcwd()
# Out:
# '/Users/cgouvatsou/Documents'

# %%
#os.makedirs("artifacts/data_ingestion", exist_ok=True)

# %%
dataset_id = "nazmul0087/ct-kidney-dataset-normal-cyst-tumor-and-stone"
os.system(f"kaggle datasets download -d {dataset_id} -p data --unzip")
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nazmul0087/ct-kidney-dataset-normal-cyst-tumor-and-stone
# License(s): Attribution 4.0 International (CC BY 4.0)
# Downloading ct-kidney-dataset-normal-cyst-tumor-and-stone.zip to data
# 100%|██████████| 1.52G/1.52G [01:21<00:00, 20.0MB/s]
# 0

# %%
from dataclasses import dataclass
from pathlib import Path


@dataclass(frozen=True)
class DataIngestionConfig:
    root_dir: Path
    source_URL: str
    local_data_file: Path
    unzip_dir: Path

# %%
os.listdir("data")
# Out:
# ['kidneyData.csv', 'CT-KIDNEY-DATASET-Normal-Cyst-Tumor-Stone']
